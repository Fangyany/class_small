# %%
import numpy as np
import os
import sys
from fractions import gcd
from numbers import Number

import torch
from torch import Tensor, nn
from torch.nn import functional as F

from data import ArgoDataset, collate_fn
from utils import gpu, to_long,  Optimizer, StepLR

from layers import Conv1d, Res1d, Linear, LinearRes, Null
from numpy import float64, ndarray
from typing import Any, Callable, Dict, List, Optional, Tuple, Type, Union

from lanegcn import PredNet, get_model
import torch
from torch.utils.data import Sampler, DataLoader

import matplotlib.pyplot as plt

config, Dataset, collate_fn, net, loss, post_process, opt = get_model()
import os

import argparse
import numpy as np
import random
import sys
import time
import shutil
from importlib import import_module
from numbers import Number

import torch
from torch.utils.data import Sampler, DataLoader


from utils import Logger, load_pretrain
def worker_init_fn(pid):
    np_seed = int(pid)
    np.random.seed(np_seed)
    random_seed = np.random.randint(2 ** 32 - 1)
    random.seed(random_seed)


dataset = Dataset(config["train_split"], config, train=True)
train_loader = DataLoader(
    dataset,
    batch_size=config["batch_size"],
    num_workers=config["workers"],
    shuffle=False,
    collate_fn=collate_fn,
    pin_memory=True,
    worker_init_fn=worker_init_fn,
    drop_last=True,
)


for i, data in enumerate(train_loader):
    break

# %%
from lanegcn import ActorNet, MapNet, actor_gather, graph_gather
actor_net = ActorNet(config)
map_net = MapNet(config)

# construct actor feature
actors, actor_idcs = actor_gather(gpu(data["feats"]))
actor_ctrs = gpu(data["ctrs"])
actors = actor_net(actors)

# construct map features
graph = graph_gather(to_long(gpu(data["graph"])))
nodes, node_idcs, node_ctrs = map_net(graph)

# %%
from lanegcn import A2A,A2M,M2A,M2M
a2m = A2M(config)
m2m = M2M(config)
m2a = M2A(config)
a2a = A2A(config)

# %%
nodes = a2m(nodes, graph, actors, actor_idcs, actor_ctrs)
nodes = m2m(nodes, graph)
actors = m2a(actors, actor_idcs, actor_ctrs, nodes, node_idcs, node_ctrs)
actors = a2a(actors, actor_idcs, actor_ctrs)

# %%
from lanegcn import GAT
gat = GAT(config)
actors_gat = gat(actors,actor_idcs,actor_ctrs,nodes, node_idcs, node_ctrs,100)
actors_gat = gat(actors,actor_idcs,actor_ctrs,actors,actor_idcs,actor_ctrs,7)

# %%
actors_gat.size()
# Out:
# torch.Size([528, 128])

# %%
agts = actors
agt_idcs = actor_idcs
agt_ctrs = actor_ctrs
ctx = actors
ctx_idcs = actor_idcs
ctx_ctrs = actor_ctrs
dist_th = 6

# %%
res = agts
batch_size = len(agt_idcs)
hi, wi = [], []
hi_count, wi_count = 0, 0
for i in range(batch_size):
    dist = agt_ctrs[i].view(-1, 1, 2) - ctx_ctrs[i].view(1, -1, 2)
    dist = torch.sqrt((dist ** 2).sum(2))
    mask = dist <= dist_th

    idcs = torch.nonzero(mask, as_tuple=False)
    if len(idcs) == 0:
        continue

    hi.append(idcs[:, 0] + hi_count)
    wi.append(idcs[:, 1] + wi_count)
    hi_count += len(agt_idcs[i])
    wi_count += len(ctx_idcs[i])
hi = torch.cat(hi, 0)
wi = torch.cat(wi, 0)

# %%
print(hi_count, wi_count)
# Out:
# 528 528

# %%
dist = agt_ctrs[0].view(-1, 1, 2) - ctx_ctrs[0].view(1, -1, 2)
dist = torch.sqrt((dist ** 2).sum(2))
mask = dist <= dist_th
print(mask)
idcs = torch.nonzero(mask, as_tuple=False)
print(idcs)
# Out:
# tensor([[ True, False, False, False, False, False],
#         [False,  True, False, False, False, False],
#         [False, False,  True, False,  True, False],
#         [False, False, False,  True, False, False],
#         [False, False,  True, False,  True, False],
#         [False, False, False, False, False,  True]])
# tensor([[0, 0],
#         [1, 1],
#         [2, 2],
#         [2, 4],
#         [3, 3],
#         [4, 2],
#         [4, 4],
#         [5, 5]])

# %%
fc = nn.Linear(128, 128)
att_fc = nn.Linear(2*128, 1)
dist = nn.Sequential(
            nn.Linear(2, 128),
            nn.ReLU(inplace=True),
            Linear(128, 128, norm='GN', ng=1),
        )

# %%
agt_ctrs = torch.cat(agt_ctrs, 0)
ctx_ctrs = torch.cat(ctx_ctrs, 0)
distance = agt_ctrs[hi] - ctx_ctrs[wi]
distance_dim = dist(distance)

# %%
distance_dim.size()
# Out:
# torch.Size([892, 128])

# %%
z = fc(agts)
z_i = z[hi]
z_j = z[wi]

# %%
z_ij = torch.cat((z_i, z_j), dim =-1)
a_ij = att_fc(z_ij)
print(a_ij.size())
# Out:
# torch.Size([892, 1])

# %%
torch.nonzero(hi==2).squeeze()
# Out:
# tensor([2, 3])

# %%
hi[torch.nonzero(hi==2).squeeze()]
# Out:
# tensor([2, 2])

# %%
print(z_i.size(), z_j.size())
print(hi[:10],wi[:10])
# Out:
# torch.Size([892, 128]) torch.Size([892, 128])
# tensor([0, 1, 2, 2, 3, 4, 4, 5, 6, 7]) tensor([0, 1, 2, 4, 3, 2, 4, 5, 6, 7])

# %%
a_ij.size()
# Out:
# torch.Size([892, 1])

# %%
alpha_ij = []
for i in range(527):
    # print(a_ij[torch.nonzero(hi==i).squeeze()])
    index = torch.nonzero(hi==i).squeeze(-1)
    alpha_ij.append(F.softmax(a_ij[index], dim=0))
    
    a_ij_new = F.softmax(a_ij[index], dim=0)
    # print(a_ij_new)
    x_i = z_i[torch.nonzero(hi==i)[0]]
    x_j = z_j[index]
    print(x_i.size(), x_j.size())
    distance_dim_ij = distance_dim[index]
    print(distance_dim_ij.size())

    x_j_new = torch.cat((distance_dim_ij, x_j), dim=-1)
    print(x_j_new.size())
    print('*', (a_ij_new*x_j_new).size())



    x_j_new_ = torch.sum(a_ij_new*x_j_new, dim=0).unsqueeze(0)
    print("1", x_j_new_.size())
    
    x = torch.cat((x_i, x_j_new_), dim=1)
    print(x.size())
    # break
# print(alpha_ij[15])
# Out:
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([4, 128])
# torch.Size([4, 128])
# torch.Size([4, 256])
# * torch.Size([4, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([6, 128])
# torch.Size([6, 128])
# torch.Size([6, 256])
# * torch.Size([6, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([6, 128])
# torch.Size([6, 128])
# torch.Size([6, 256])
# * torch.Size([6, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([4, 128])
# torch.Size([4, 128])
# torch.Size([4, 256])
# * torch.Size([4, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([4, 128])
# torch.Size([4, 128])
# torch.Size([4, 256])
# * torch.Size([4, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([8, 128])
# torch.Size([8, 128])
# torch.Size([8, 256])
# * torch.Size([8, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([4, 128])
# torch.Size([4, 128])
# torch.Size([4, 256])
# * torch.Size([4, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([7, 128])
# torch.Size([7, 128])
# torch.Size([7, 256])
# * torch.Size([7, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([5, 128])
# torch.Size([5, 128])
# torch.Size([5, 256])
# * torch.Size([5, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([6, 128])
# torch.Size([6, 128])
# torch.Size([6, 256])
# * torch.Size([6, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([7, 128])
# torch.Size([7, 128])
# torch.Size([7, 256])
# * torch.Size([7, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([8, 128])
# torch.Size([8, 128])
# torch.Size([8, 256])
# * torch.Size([8, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([8, 128])
# torch.Size([8, 128])
# torch.Size([8, 256])
# * torch.Size([8, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([6, 128])
# torch.Size([6, 128])
# torch.Size([6, 256])
# * torch.Size([6, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([5, 128])
# torch.Size([5, 128])
# torch.Size([5, 256])
# * torch.Size([5, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([5, 128])
# torch.Size([5, 128])
# torch.Size([5, 256])
# * torch.Size([5, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([5, 128])
# torch.Size([5, 128])
# torch.Size([5, 256])
# * torch.Size([5, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([5, 128])
# torch.Size([5, 128])
# torch.Size([5, 256])
# * torch.Size([5, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([4, 128])
# torch.Size([4, 128])
# torch.Size([4, 256])
# * torch.Size([4, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([5, 128])
# torch.Size([5, 128])
# torch.Size([5, 256])
# * torch.Size([5, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([5, 128])
# torch.Size([5, 128])
# torch.Size([5, 256])
# * torch.Size([5, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# ...
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([3, 128])
# torch.Size([3, 128])
# torch.Size([3, 256])
# * torch.Size([3, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([1, 128])
# torch.Size([1, 128])
# torch.Size([1, 256])
# * torch.Size([1, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])
# torch.Size([1, 128]) torch.Size([2, 128])
# torch.Size([2, 128])
# torch.Size([2, 256])
# * torch.Size([2, 256])
# 1 torch.Size([1, 256])
# torch.Size([1, 384])

# %%
alpha_ij
# Out:
# [tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4997],
#          [0.5003]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4997],
#          [0.5003]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5024],
#          [0.4976]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3248],
#          [0.3357],
#          [0.3396]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5024],
#          [0.4976]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3407],
#          [0.3236],
#          [0.3358]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3248],
#          [0.3357],
#          [0.3396]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3248],
#          [0.3357],
#          [0.3396]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3407],
#          [0.3236],
#          [0.3358]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4999],
#          [0.5001]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4999],
#          [0.5001]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3407],
#          [0.3236],
#          [0.3358]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5006],
#          [0.4994]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4990],
#          [0.5010]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4990],
#          [0.5010]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5006],
#          [0.4994]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5012],
#          [0.4988]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5012],
#          [0.4988]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4992],
#          [0.5008]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4999],
#          [0.5001]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4999],
#          [0.5001]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4975],
#          [0.5025]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4998],
#          [0.5002]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4999],
#          [0.5001]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4998],
#          [0.5002]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4975],
#          [0.5025]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5017],
#          [0.4983]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4999],
#          [0.5001]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4992],
#          [0.5008]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5017],
#          [0.4983]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5000],
#          [0.5000]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5003],
#          [0.4997]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4999],
#          [0.5001]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5003],
#          [0.4997]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5000],
#          [0.5000]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4999],
#          [0.5001]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4998],
#          [0.5002]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4998],
#          [0.5002]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5054],
#          [0.4946]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3325],
#          [0.3350],
#          [0.3325]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.2495],
#          [0.2514],
#          [0.2496],
#          [0.2495]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5011],
#          [0.4989]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4984],
#          [0.5016]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5035],
#          [0.4965]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3339],
#          [0.3339],
#          [0.3322]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5035],
#          [0.4965]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5018],
#          [0.4982]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.1656],
#          [0.1663],
#          [0.1677],
#          [0.1657],
#          [0.1663],
#          [0.1684]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.1660],
#          [0.1668],
#          [0.1654],
#          [0.1683],
#          [0.1667],
#          [0.1668]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.2495],
#          [0.2514],
#          [0.2496],
#          [0.2495]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.2501],
#          [0.2500],
#          [0.2498],
#          [0.2501]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.1244],
#          [0.1244],
#          [0.1249],
#          [0.1239],
#          [0.1260],
#          [0.1249],
#          [0.1250],
#          [0.1265]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5013],
#          [0.4987]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3333],
#          [0.3335],
#          [0.3332]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.2508],
#          [0.2497],
#          [0.2488],
#          [0.2507]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3336],
#          [0.3336],
#          [0.3328]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5005],
#          [0.4995]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.1428],
#          [0.1430],
#          [0.1427],
#          [0.1432],
#          [0.1428],
#          [0.1426],
#          [0.1428]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.2004],
#          [0.1997],
#          [0.2004],
#          [0.1996],
#          [0.1999]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4998],
#          [0.5002]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.1664],
#          [0.1672],
#          [0.1664],
#          [0.1658],
#          [0.1671],
#          [0.1672]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.1420],
#          [0.1420],
#          [0.1426],
#          [0.1439],
#          [0.1425],
#          [0.1427],
#          [0.1444]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5054],
#          [0.4946]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4998],
#          [0.5002]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3332],
#          [0.3333],
#          [0.3335]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3339],
#          [0.3329],
#          [0.3332]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5000],
#          [0.5000]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.1244],
#          [0.1249],
#          [0.1243],
#          [0.1239],
#          [0.1260],
#          [0.1249],
#          [0.1250],
#          [0.1265]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.1244],
#          [0.1244],
#          [0.1249],
#          [0.1239],
#          [0.1260],
#          [0.1249],
#          [0.1250],
#          [0.1265]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.1655],
#          [0.1662],
#          [0.1677],
#          [0.1661],
#          [0.1663],
#          [0.1683]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.2000],
#          [0.1998],
#          [0.2005],
#          [0.1997],
#          [0.2000]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.2000],
#          [0.1998],
#          [0.2005],
#          [0.1997],
#          [0.2000]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4984],
#          [0.5016]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5045],
#          [0.4955]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3368],
#          [0.3320],
#          [0.3312]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5015],
#          [0.4985]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5036],
#          [0.4964]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5001],
#          [0.4999]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5042],
#          [0.4958]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5015],
#          [0.4985]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3374],
#          [0.3314],
#          [0.3313]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5002],
#          [0.4998]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3334],
#          [0.3333],
#          [0.3332]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5002],
#          [0.4998]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5045],
#          [0.4955]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5006],
#          [0.4994]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5006],
#          [0.4994]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5045],
#          [0.4955]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5015],
#          [0.4985]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5015],
#          [0.4985]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4999],
#          [0.5001]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3299],
#          [0.3299],
#          [0.3401]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5000],
#          [0.5000]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3366],
#          [0.3266],
#          [0.3367]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4996],
#          [0.5004]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5028],
#          [0.4972]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5028],
#          [0.4972]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4996],
#          [0.5004]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4966],
#          [0.5034]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4966],
#          [0.5034]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5000],
#          [0.5000]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5000],
#          [0.5000]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4994],
#          [0.5006]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4994],
#          [0.5006]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5000],
#          [0.5000]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5000],
#          [0.5000]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5004],
#          [0.4996]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5004],
#          [0.4996]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5001],
#          [0.4999]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4998],
#          [0.5002]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3335],
#          [0.3332],
#          [0.3334]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3344],
#          [0.3316],
#          [0.3340]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5021],
#          [0.4979]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5003],
#          [0.4997]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4996],
#          [0.5004]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5000],
#          [0.5000]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5054],
#          [0.4946]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3332],
#          [0.3338],
#          [0.3331]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5054],
#          [0.4946]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5000],
#          [0.5000]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5000],
#          [0.5000]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3331],
#          [0.3338],
#          [0.3331]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5009],
#          [0.4991]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5006],
#          [0.4994]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3320],
#          [0.3326],
#          [0.3355]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4964],
#          [0.5036]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5000],
#          [0.5000]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.1999],
#          [0.2003],
#          [0.2001],
#          [0.2003],
#          [0.1994]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5009],
#          [0.4991]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3366],
#          [0.3326],
#          [0.3309]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5006],
#          [0.4994]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5000],
#          [0.5000]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5030],
#          [0.4970]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5016],
#          [0.4984]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4964],
#          [0.5036]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4973],
#          [0.5027]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5043],
#          [0.4957]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.2002],
#          [0.2001],
#          [0.2000],
#          [0.2003],
#          [0.1994]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.2502],
#          [0.2501],
#          [0.2504],
#          [0.2493]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.2002],
#          [0.2001],
#          [0.2000],
#          [0.2003],
#          [0.1994]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.2002],
#          [0.2001],
#          [0.2000],
#          [0.2003],
#          [0.1994]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5016],
#          [0.4984]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5022],
#          [0.4978]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5003],
#          [0.4997]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5003],
#          [0.4997]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5022],
#          [0.4978]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5015],
#          [0.4985]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5015],
#          [0.4985]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4968],
#          [0.5032]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5018],
#          [0.4982]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5003],
#          [0.4997]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5027],
#          [0.4973]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5027],
#          [0.4973]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5003],
#          [0.4997]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4968],
#          [0.5032]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5018],
#          [0.4982]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4992],
#          [0.5008]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5009],
#          [0.4991]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4992],
#          [0.5008]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4997],
#          [0.5003]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4997],
#          [0.5003]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5009],
#          [0.4991]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3342],
#          [0.3322],
#          [0.3336]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5015],
#          [0.4985]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5004],
#          [0.4996]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4989],
#          [0.5011]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4989],
#          [0.5011]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4978],
#          [0.5022]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4978],
#          [0.5022]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4975],
#          [0.5025]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5005],
#          [0.4995]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5005],
#          [0.4995]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4997],
#          [0.5003]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3313],
#          [0.3342],
#          [0.3346]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5069],
#          [0.4931]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5069],
#          [0.4931]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5035],
#          [0.4965]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5035],
#          [0.4965]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5002],
#          [0.4998]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5002],
#          [0.4998]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5010],
#          [0.4990]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3354],
#          [0.3325],
#          [0.3321]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5010],
#          [0.4990]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4999],
#          [0.5001]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4999],
#          [0.5001]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5000],
#          [0.5000]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5022],
#          [0.4978]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5000],
#          [0.5000]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5004],
#          [0.4996]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5025],
#          [0.4975]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5004],
#          [0.4996]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4998],
#          [0.5002]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3333],
#          [0.3341],
#          [0.3326]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5002],
#          [0.4998]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5002],
#          [0.4998]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3333],
#          [0.3341],
#          [0.3326]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4998],
#          [0.5002]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4999],
#          [0.5001]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.2500],
#          [0.2499],
#          [0.2499],
#          [0.2501]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5001],
#          [0.4999]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.2498],
#          [0.2501],
#          [0.2500],
#          [0.2502]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3333],
#          [0.3332],
#          [0.3334]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3333],
#          [0.3341],
#          [0.3326]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3331],
#          [0.3333],
#          [0.3336]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4999],
#          [0.5001]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4998],
#          [0.5002]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4995],
#          [0.5005]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5001],
#          [0.4999]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5001],
#          [0.4999]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5046],
#          [0.4954]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5046],
#          [0.4954]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4995],
#          [0.5005]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4971],
#          [0.5029]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4956],
#          [0.5044]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4956],
#          [0.5044]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4971],
#          [0.5029]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4983],
#          [0.5017]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4983],
#          [0.5017]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4998],
#          [0.5002]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3358],
#          [0.3361],
#          [0.3282]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5059],
#          [0.4941]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4997],
#          [0.5003]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5000],
#          [0.5000]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3331],
#          [0.3334],
#          [0.3335]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5051],
#          [0.4949]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5051],
#          [0.4949]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4982],
#          [0.5018]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4982],
#          [0.5018]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5004],
#          [0.4996]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5004],
#          [0.4996]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5060],
#          [0.4940]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5060],
#          [0.4940]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5058],
#          [0.4942]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5000],
#          [0.5000]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3359],
#          [0.3359],
#          [0.3282]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5058],
#          [0.4942]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5058],
#          [0.4942]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3349],
#          [0.3345],
#          [0.3306]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5036],
#          [0.4964]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5003],
#          [0.4997]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5008],
#          [0.4992]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.3364],
#          [0.3319],
#          [0.3317]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5008],
#          [0.4992]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5036],
#          [0.4964]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5034],
#          [0.4966]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5035],
#          [0.4965]], grad_fn=<SoftmaxBackward>),
#  tensor([[0.5033],
#          [0.4967]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4992],
#          [0.5008]], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([1.], grad_fn=<SoftmaxBackward>),
#  tensor([[0.4992],
#          [0.5008]], grad_fn=<SoftmaxBackward>)]

# %%
alpha_ij = []
h_new = []
for i in range(hi[-1]+1):
    index = torch.nonzero(hi==i).squeeze(-1)

    alpha_ij.append(F.softmax(a_ij[index], dim=0))

    a_ij_new = F.softmax(a_ij[index], dim=0)
    
    x_i = z_i[torch.nonzero(hi==i)[0]]
    x_j = z_j[index]
    distance_dim_ij = distance_dim[index]

    x_j_new = torch.cat((distance_dim_ij, x_j), dim=-1)
    # print((alpha*x_j_new).size())

    x_j_new_ = torch.sum(a_ij_new*x_j_new, dim=0).unsqueeze(0)

    # print(x_i.size(), x_j_new_.size())
    h_new.append(torch.cat((x_i, x_j_new_), -1))
    # break

# %%
h_new_ = torch.cat(h_new)
h_new_.size()
# Out:
# torch.Size([528, 384])

# %%
norm = nn.GroupNorm(1, 128*3)
linear = Linear(128*3, 128, norm='GN', ng=1, act=False)
relu = nn.ReLU(inplace=True)

# %%
agts = norm(h_new_)
agts = relu(agts)

agts = linear(agts)
agts += res
gts = relu(agts)

# %%
gts.size()
# Out:
# torch.Size([528, 128])
